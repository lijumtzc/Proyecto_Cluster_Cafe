# %%
# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 

# dataset = pd.DataFrame(Store Nbr, Valor2019, Valor2020, Región Nestlé, Estado, Canal, Material Goup, FormatoEquivalente)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
# Cargar los paquetes necesarios
import numpy as np
import pandas as pd

# Importar estilo de trama
import matplotlib as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.cluster import KMeans
df = dataset
df_x = dataset[['Valor2019', 'Valor2020']]
scaler = StandardScaler()
X_std = scaler.fit_transform(df_x)
ctd=KMeans(n_clusters=5, random_state=0)
model =ctd.fit(X_std)
centroids = model.cluster_centers_
colores = ['red', 'blue', 'yellow', 'green', 'pink']

n_clusters = 5
idx = np.argsort(model.cluster_centers_.sum(axis=1))
lut = np.zeros_like(idx)
lut[idx] = np.arange(n_clusters)
df['cluster'] = lut[model.labels_]

c_0 = df[df['cluster']==0]
c_1 = df[df['cluster']==1]
c_2 = df[df['cluster']==2]
c_3 = df[df['cluster']==3]
c_4 = df[df['cluster']==4]

dataset['cluster'] = lut[model.labels_]

data_0 = pd.DataFrame(c_0)
data_0.to_csv('Cluster_0.csv')
data_1 = pd.DataFrame(c_1)
data_1.to_csv('Cluster_1.csv')
data_2 = pd.DataFrame(c_2)
data_2.to_csv('Cluster_2.csv')
data_3 = pd.DataFrame(c_3)
data_3.to_csv('Cluster_3.csv')
data_4 = pd.DataFrame(c_4)
data_4.to_csv('Cluster_4.csv')

plt.scatter(c_0['Valor2019'], c_0['Valor2020'], color = '#ffa372')
plt.scatter(c_1['Valor2019'], c_1['Valor2020'], color = '#318fb5')
plt.scatter(c_2['Valor2019'], c_2['Valor2020'], color = '#4d4c7d')
plt.scatter(c_3['Valor2019'], c_3['Valor2020'], color = '#fa26a0')
plt.scatter(c_4['Valor2019'], c_4['Valor2020'], color = '#4cbbb9')

plt.show()

dataset = lut[model.labels_]


# El código siguiente, que crea un dataframe y quita las filas duplicadas, siempre se ejecuta y actúa como un preámbulo del script: 

# dataset = pd.DataFrame(Store Nbr, Valor2019, Valor2020, Región Nestlé, Estado, Canal, Material Goup, FormatoEquivalente)
# dataset = dataset.drop_duplicates()

# Pegue o escriba aquí el código de script:
# Cargar los paquetes necesarios
import numpy as np
import pandas as pd

# Importar estilo de trama
import matplotlib as plt
#plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.cluster import KMeans
df = dataset
df_x = dataset[['Valor2019', 'Valor2020']]
scaler = StandardScaler()
X_std = scaler.fit_transform(df_x)
ctd=KMeans(n_clusters=5, random_state=0)
model =ctd.fit(X_std)
centroids = model.cluster_centers_
colores = ['red', 'blue', 'yellow', 'green', 'pink']

n_clusters = 5
idx = np.argsort(model.cluster_centers_.sum(axis=1))
lut = np.zeros_like(idx)
lut[idx] = np.arange(n_clusters)
df['cluster'] = lut[model.labels_]

c_0 = df[df['cluster']==0]
c_1 = df[df['cluster']==1]
c_2 = df[df['cluster']==2]
c_3 = df[df['cluster']==3]
c_4 = df[df['cluster']==4]

dataset['cluster'] = lut[model.labels_]

df_group = dataset.groupby('cluster').agg(**{'cuenta':('Store Name', 'count')}).reset_index()
plt.bar(df_group['cluster'], df_group['cuenta'], color = '#726a95')
plt.show()
